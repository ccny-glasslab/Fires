# %%
import os
import time
import random
from PIL import Image
from skimage import io
from skimage.transform import resize
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from pathlib import Path
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
# %matplotlib inline

MAE = tf.keras.losses.MeanAbsoluteError()
MSE = tf.keras.losses.MeanSquaredError()

# %%
SAVED_MODEL_PATH = "https://tfhub.dev/captain-pool/esrgan-tf2/1"
model = hub.load(SAVED_MODEL_PATH)

# %%
min_temps = {}
max_temps = {}
band_mean = {}
band_std = {}

def png(image, in_path, out_path):
    band = np.load(in_path + image)
    zscore = (band - band.mean())/band.std()
    norm = (zscore-zscore.min())/(zscore.max()-zscore.min())
    final = norm*255
    
    min_temps[image[:-5]] = zscore.min()
    max_temps[image[:-5]] = zscore.max()
    band_mean[image[:-5]] = band.mean()
    band_std[image[:-5]] = band.std()
    
    GSband = np.zeros((band.shape[0], band.shape[1], 3))
    GSband[:,:,0]= final
    GSband[:,:,1]= final
    GSband[:,:,2]= final
    GSband = GSband.astype('uint8')
    png = Image.fromarray(GSband)
    image = image[:-4]
    png.save(out_path + image + ".png")

def random_pngs():
    path = '../../GOES_Files/diff_files/'
    for x in range(20):
        file = random.choice(os.listdir(path))
        png(file, path, '../../GOES_Files/png_files/')

# %%
# random_pngs()

# %% [markdown]
# ## Image Normalization

# %%
path = '../../GOES_Files/diff_files/'
image = random.choice(os.listdir(path))
band = np.load(path + image)

zscore = (band - band.mean())/band.std()

# %%
fig, ax = plt.subplots()
x = ax.hist(zscore.flatten(), bins=100)
ax.set_title('z-scores')
print(zscore.min(), zscore.std(), zscore.mean(), zscore.max())
# Out:
# -2.3551228 0.99999994 1.171875e-08 15.107864

# %%
zscore.shape
zscore.min()
# Out:
# -2.3551228

# %%
norm = (zscore-zscore.min())/(zscore.max()-zscore.min())
fig, ax = plt.subplots()
x = ax.hist(norm.flatten(), bins=100)
ax.set_title('Normalized Image')
print(norm.min(), norm.std(), norm.mean(), norm.max())
# Out:
# 0.0 0.057263967 0.13486369 1.0

# %%
def preprocess_image(image_path):
    #need to divide values
    hr_image = tf.image.decode_image(tf.io.read_file(image_path))
    if hr_image.shape[-1] == 4:
        hr_image = hr_image[...,:-1]
    hr_size = (tf.convert_to_tensor(hr_image.shape[:-1]) // 2) * 2
    hr_image = tf.image.crop_to_bounding_box(hr_image, 0, 0, hr_size[0], hr_size[1])

    hr_image = tf.cast(hr_image, tf.float32)
    return tf.expand_dims(hr_image, 0)

def downscale_image(image):
    image_size = []
    if len(image.shape) == 3:
        image_size = [image.shape[1], image.shape[0]]
    else:
        raise ValueError("Dimension mismatch. Can work only on single image.")

    image = tf.squeeze(tf.cast(tf.clip_by_value(image, 0, 255), tf.uint8))

    lr_image = np.asarray(
#     Image.fromarray(image.numpy()).resize([image_size[0] // 4, image_size[1] // 4], Image.BICUBIC))
    Image.fromarray(image.numpy()).resize([image_size[0] // 2, image_size[1] // 2], Image.NEAREST))

    lr_image = tf.expand_dims(lr_image, 0)
    lr_image = tf.cast(lr_image, tf.float32)
    return lr_image


def m_learning(fileID):
    band = fileID[-58:-56]
    hr_image = preprocess_image(fileID)
    hr_image = tf.squeeze(hr_image)
#     print(f'hr_max = {hr_image.numpy().max()}, hr_min = {hr_image.numpy().min()}, hr_mean = {hr_image.numpy().mean()}, hr_std = {hr_image.numpy().std()}')
    lr_image = downscale_image(hr_image)
#     print(f'lr_max = {lr_image.numpy().max()}, lr_min = {lr_image.numpy().min()}, lr_mean = {lr_image.numpy().mean()}, lr_std = {lr_image.numpy().std()}')
    fake_image = model(lr_image)
#     print(f'fake_max = {fake_image.numpy().max()}, fake_min = {fake_image.numpy().min()}, fake_mean = {fake_image.numpy().mean()}, fake_std = {fake_image.numpy().std()}')
#     print(((fake_image.numpy()<=0).sum()*100)/(500*500*3))
    fake_image = tf.squeeze(fake_image)
    fake_image = resize(fake_image, (500, 500, 3))
    lr_image = resize(tf.squeeze(lr_image), (500, 500, 3))

    controlmae = MAE(hr_image, lr_image).numpy()
    controlrmse = np.sqrt(MSE(hr_image, lr_image).numpy())
    mae = MAE(hr_image, fake_image).numpy()
    rmse = np.sqrt(MSE(hr_image, fake_image).numpy())
    
    controlmae = (controlmae*(max_temps[fileID[27:-5]] - min_temps[fileID[27:-5]])/255+min_temps[fileID[27:-5]])*band_std[fileID[27:-5]]+band_mean[fileID[27:-5]]
    controlrmse = (controlrmse*(max_temps[fileID[27:-5]] - min_temps[fileID[27:-5]])/255+min_temps[fileID[27:-5]])*band_std[fileID[27:-5]]+band_mean[fileID[27:-5]]
    mae = (mae*(max_temps[fileID[27:-5]] - min_temps[fileID[27:-5]])/255+min_temps[fileID[27:-5]])*band_std[fileID[27:-5]]+band_mean[fileID[27:-5]]
    rmse = (rmse*(max_temps[fileID[27:-5]] - min_temps[fileID[27:-5]])/255+min_temps[fileID[27:-5]])*band_std[fileID[27:-5]]+band_mean[fileID[27:-5]]
    
    return ({'File': fileID, 'Control MAE': controlmae, 'Control RMSE': controlrmse, 'MAE': mae, 'RMSE': rmse, 'fake_img': fake_image})

# %%
table = []
path = '../../GOES_Files/png_files/'
for file in os.listdir(path):
    try:
        table.append(m_learning(path + file))
    except:
        print(file)
# Out:
# .ipynb_checkpoints

# %%
x = pd.DataFrame(table)
agg_function = {'Control MAE': 'mean', 'Control RMSE': 'mean', 'MAE': 'mean', 'RMSE': 'mean'}
y = x.agg(agg_function)
y
# Out:
# Control MAE    -3.360441
# Control RMSE   -3.020194
# MAE            -3.095027
# RMSE           -2.642027
# dtype: float64

# %% [markdown]
# ## Which values become out of bounds during sharpening?

# %%
path = '../../GOES_Files/png_files/'
random.seed(42)
datafiles = [datafile for datafile in os.listdir(path) if datafile.endswith('.png')]
fileID = path + random.choice(datafiles)

hr_image = preprocess_image(fileID)
hr_image = tf.squeeze(hr_image)
#     print(f'hr_max = {hr_image.numpy().max()}, hr_min = {hr_image.numpy().min()}, hr_mean = {hr_image.numpy().mean()}, hr_std = {hr_image.numpy().std()}')
lr_image = downscale_image(hr_image)
#     print(f'lr_max = {lr_image.numpy().max()}, lr_min = {lr_image.numpy().min()}, lr_mean = {lr_image.numpy().mean()}, lr_std = {lr_image.numpy().std()}')
fake_image = model(lr_image)
print(f'fake_max = {fake_image.numpy().max()}, fake_min = {fake_image.numpy().min()}, fake_mean = {fake_image.numpy().mean()}, fake_std = {fake_image.numpy().std()}')
print(str(((fake_image.numpy()<0).sum()*100)/(500*500*3)) + '% of values are less than 0')
print(str(((fake_image.numpy()>255).sum()*100)/(500*500*3)) + '% of values are greater than 255')

img = fake_image.numpy().squeeze()[:,:,0]

smallValues = img<0
largeValues = img>255

fig, ax = plt.subplots(1, 4, figsize=(15, 10))

ax[0].imshow(img, aspect='equal')
ax[0].set_title('Fake image')
ax[0].axis('off')

ax[1].imshow(smallValues, aspect='equal')
ax[1].set_title('Values less than 0')
ax[1].axis('off')

ax[2].imshow(largeValues, aspect='equal')
ax[2].set_title('Values greater than 255')
ax[2].axis('off')

ax[3].imshow(hr_image.numpy()/255, aspect='equal')
ax[3].set_title('Original image')
ax[3].axis('off')

plt.axis('off')
plt.show()
# Out:
# fake_max = 579.7890625, fake_min = -56.87757110595703, fake_mean = 31.180389404296875, fake_std = 21.361454010009766
# 0.04373333333333333% of values are less than 0
# 0.002% of values are greater than 255

# %%
hr_image.shape
# Out:
# TensorShape([500, 500, 3])

# %% [markdown]
# ## Evaluating Error (not un-normalized)

# %%
path = '../../GOES_Files/png_files/'
fileID = path + random.choice(os.listdir(path))

band = fileID[-58:-56]
hr_image = preprocess_image(fileID)
hr_image = tf.squeeze(hr_image)
lr_image = downscale_image(hr_image)
fake_image = model(lr_image)
fake_image = tf.squeeze(fake_image)
fake_image = resize(fake_image, (500, 500, 3))
lr_image = resize(tf.squeeze(lr_image), (500, 500, 3))

# %%
HF = hr_image-lr_image
HF = HF.numpy().flatten()

PHF = fake_image-lr_image
PHF = PHF.flatten()

Error = fake_image-hr_image
Error = Error.numpy().flatten()

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

x = ax[0].hist(HF, bins=np.linspace(-5, 5, 100))
ax[0].set_title('HF = HR – LR')
print(HF.min(), HF.std(), HF.mean(), HF.max())

y = ax[1].hist(PHF, bins=np.linspace(-5, 5, 100))
ax[1].set_title('PHF = UM – LR')
print(PHF.min(), PHF.std(), PHF.mean(), PHF.max())

z = ax[2].hist(Error, bins=np.linspace(-5, 5, 100))
ax[2].set_title('Error = UM – HR')
print(Error.min(), Error.std(), Error.mean(), Error.max())

plt.setp(ax, xlim=(-5, 5), ylim=(0, 50000))
plt.show()
# Out:
# -74.3125 3.3278382 -0.01043375 119.5625
# -74.8763 3.2737892 -1.7696328 131.33353
# -128.10144 4.528763 -1.7591994 165.50917

# %%
path = '../../GOES_Files/png_files/'
image = Image.open(path + random.choice(os.listdir(path)))
image = np.asarray(image)
plt.imshow(image)
