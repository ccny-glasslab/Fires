# %%
from skimage import io
from matplotlib import pyplot as plt
import numpy as np

# %%
img = io.imread("GEO2GRID/GOES-17_ABI_RadF_C07_20190906_170034_cali.tif")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (556, 541, 2)

# %%
goes = np.squeeze(img[:,:,0])

# %%
fig, ax = plt.subplots(1,1, figsize=(10,15))
im = ax.imshow(goes, interpolation = 'nearest')
