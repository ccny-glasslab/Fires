# %%
import xarray as xr
import metpy
import cartopy.crs as ccrs
from pyresample import geometry, grid
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import stats
import os

# %%
geos = diff.metpy.cartopy_crs
goes_params = geos.proj4_params

pc = ccrs.PlateCarree()
pc_extents = [-124.25, -114.25, 32.25, 42.25]
pc_params = pc.proj4_params
target_extents = [pc_extents[0],
                    pc_extents[2],
                    pc_extents[1],
                    pc_extents[3]]
target_rows = 500
target_cols = 500
shape = [target_rows, target_cols]

def create_npy(array, file):
    x = np.asarray(array)
    source_area = geometry.AreaDefinition.from_cf(file)
    target_area = geometry.AreaDefinition.from_extent('CA', pc_params, shape, target_extents)
    return(grid.get_resampled_image(target_area, source_area, x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-8079ac0377da> in <module>
# ----> 1 geos = diff.metpy.cartopy_crs
#       2 goes_params = geos.proj4_params
#       3
#       4 pc = ccrs.PlateCarree()
#       5 pc_extents = [-124.25, -114.25, 32.25, 42.25]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'metpy'

# %% [markdown]
# # All the Bands

# %%
data = xr.open_dataset('../GOES_Files/test_files/OR_ABI-L2-MCMIPC-M3_G17_s20183171802219_e20183171804592_c20183171805082.nc')
for n in range (1,17):
    if n < 10:
        band = '0' + str(n)
    else:
        band = str(n)
        
    dat = data.metpy.parse_cf('CMI_C' + band)
    geos = dat.metpy.cartopy_crs
    rad = dat.data

    np.save('../GOES_Files/test_files/multiband_npys/' + band, create_npy(rad, data))
    data.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-16d0e74ecf72> in <module>
#      10     rad = dat.data
#      11
# ---> 12     np.save('../GOES_Files/test_files/multiband_npys/' + band, create_npy(rad, data))
#      13     data.close()
#
# NameError: name 'create_npy' is not defined

# %%
img_array = np.load("../GOES_Files/test_files/multiband_npys/13.npy")
plt.imshow(img_array, aspect='equal', cmap='Greens_r')

plt.axis('off')
plt.show()

# %% [markdown]
# # 7 and 14 Brightness Temperatures

# %%
myFile = xr.open_dataset('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C07_G17_s20183171802219_e20183171805003_c20183171805037.nc')
rad = myFile.metpy.parse_cf('Rad')
fk1 = float(myFile.metpy.parse_cf('planck_fk1'))
fk2 = float(myFile.metpy.parse_cf('planck_fk2'))
bc1 = float(myFile.metpy.parse_cf('planck_bc1'))
bc2 = float(myFile.metpy.parse_cf('planck_bc2'))
temp07 = (fk2/(xr.ufuncs.log(fk1/rad + 1)) - bc1)/bc2
np.save('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C07_G17_s20183171802219_e20183171805003_c20183171805037', create_npy(temp07, myFile))

myFile = xr.open_dataset('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C14_G17_s20183171802219_e20183171804592_c20183171805038.nc')
rad = myFile.metpy.parse_cf('Rad')
fk1 = float(myFile.metpy.parse_cf('planck_fk1'))
fk2 = float(myFile.metpy.parse_cf('planck_fk2'))
bc1 = float(myFile.metpy.parse_cf('planck_bc1'))
bc2 = float(myFile.metpy.parse_cf('planck_bc2'))
temp14 = (fk2/(xr.ufuncs.log(fk1/rad + 1)) - bc1)/bc2
np.save('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C14_G17_s20183171802219_e20183171804592_c20183171805038', create_npy(temp14, myFile))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4b10a04ab445> in <module>
#       6 bc2 = float(myFile.metpy.parse_cf('planck_bc2'))
#       7 temp07 = (fk2/(xr.ufuncs.log(fk1/rad + 1)) - bc1)/bc2
# ----> 8 np.save('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C07_G17_s20183171802219_e20183171805003_c20183171805037', create_npy(temp07, myFile))
#       9
#      10 myFile = xr.open_dataset('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C14_G17_s20183171802219_e20183171804592_c20183171805038.nc')
#
# NameError: name 'create_npy' is not defined

# %%
img_array = np.load('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C07_G17_s20183171802219_e20183171805003_c20183171805037.npy')
plt.imshow(img_array, aspect='equal', cmap='hot')
plt.axis('off')
plt.show()

# %%
diff = temp07 - temp14

geos = diff.metpy.cartopy_crs
pc = ccrs.PlateCarree()

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection=pc)

x = diff.x
y = diff.y

ax.set_extent([-124.50, -114.25, 32.50, 42.00], crs=pc)

ax.imshow(diff, origin='upper',
           extent=(x.min(), x.max(), y.min(), y.max()),
           transform=geos,
           interpolation='none',
           cmap = 'hot')
ax.add_feature(ccrs.cartopy.feature.STATES)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-60483c295e2d> in <module>
# ----> 1 diff = temp07 - temp14
#       2
#       3 geos = diff.metpy.cartopy_crs
#       4 pc = ccrs.PlateCarree()
#       5
#
# ~/.conda/envs/wildfireenv3/lib/python3.8/site-packages/xarray/core/dataarray.py in func(self, other)
#    2912
#    2913             variable = (
# -> 2914                 f(self.variable, other_variable)
#    2915                 if not reflexive
#    2916                 else f(other_variable, self.variable)
#
# ~/.conda/envs/wildfireenv3/lib/python3.8/site-packages/xarray/core/variable.py in func(self, other)
#    2193             with np.errstate(all="ignore"):
#    2194                 new_data = (
# -> 2195                     f(self_data, other_data)
#    2196                     if not reflexive
# ...

# %%
np.save('../GOES_Files/test_files/difference', create_npy(diff, myFile))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e79f06a83477> in <module>
# ----> 1 np.save('../GOES_Files/test_files/difference', create_npy(diff, myFile))
#
# NameError: name 'create_npy' is not defined

# %%
img_array = np.load("../GOES_Files/test_files/difference.npy")
plt.imshow(img_array, aspect='equal', cmap='hot')
plt.colorbar(img_array)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-21c783679c65> in <module>
#       1 img_array = np.load("../GOES_Files/test_files/difference.npy")
#       2 plt.imshow(img_array, aspect='equal', cmap='hot')
# ----> 3 plt.colorbar(img_array)
#       4 plt.axis('off')
#       5 plt.show()
#
# ~/.conda/envs/wildfireenv3/lib/python3.8/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2192     if ax is None:
#    2193         ax = gca()
# -> 2194     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2195     return ret
#    2196 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# ~/.conda/envs/wildfireenv3/lib/python3.8/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2341                              'panchor']
# ...

# %%
diff = np.load("../GOES_Files/test_files/difference.npy")
diff = np.ndarray.flatten(diff)
for file in os.listdir('../GOES_Files/test_files/multiband_npys'):
    band = np.load('../GOES_Files/test_files/multiband_npys/' + file)
    band = np.ndarray.flatten(band)
    r = np.corrcoef(diff, band)
    print('band ' + file[:2] + ', r = ' + str(r[0][-1]))

# %% [markdown]
# # Correlated Band by Quantiles

# %%
diff = np.load("../GOES_Files/test_files/difference.npy")
temp07 = np.load('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C07_G17_s20183171802219_e20183171805003_c20183171805037.npy')
temp14 = np.load('../GOES_Files/test_files/OR_ABI-L1b-RadC-M3C14_G17_s20183171802219_e20183171804592_c20183171805038.npy')

# %%
temp07.max()
#look for region that's really hot
# Out:
# 407.506

# %%
hottest07 = temp07 > 263
hot07 = temp07 > np.quantile(temp07, 0.75)

fig, ax = plt.subplots(1, 3, figsize=(12, 5))
plt.figure(figsize=(10,1))

ax[0].imshow(temp07, cmap='hot', aspect='equal')
ax[0].set_title('temp07')
ax[0].axis('off')

ax[1].imshow(hottest07, cmap='hot', aspect='equal')
ax[1].set_title('Band 07 Hottest')
ax[1].axis('off')

ax[2].imshow(band13, cmap='hot', aspect='equal')
ax[2].set_title('Band 13')
ax[2].axis('off')

plt.axis('off')
plt.show()

# %%
band13 = np.load("../GOES_Files/test_files/multiband_npys/13.npy")
plt.imshow(img_array, aspect='equal', cmap='Greens_r')

plt.axis('off')
plt.show()

# %%
temp07 > np.quantile(temp07, 0.75)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True]])

# %%
np.quantile(temp07, 0.5)
# Out:
# 284.6494445800781

# %%
np.quantile(temp07, 0.75)
# Out:
# 289.9674072265625

# %%
# #Hottest pixels

# hot07 = temp07[(temp07 >= np.quantile(temp07, 0.75))]
# while len(hot07) != (500*500*0.25):
#     hot07 = np.delete(hot07, hot07.argmin())

# hot14 = temp14[(temp14 >= np.quantile(temp14, 0.75))]
# while len(hot07) != (500*500*0.25):
#     hot14 = np.delete(hot14, hot14.argmin())

# %%
hot07 = np.logical_and(temp07, temp07 > np.quantile(temp07, 0.75))
hot14 = np.logical_and(temp14, temp14 > np.quantile(temp14, 0.75))
hotboth = np.logical_and(hot07, hot14)

# %%
fig, ax = plt.subplots(1, 4, figsize=(16, 5))
plt.figure(figsize=(10,1))

ax[0].imshow(diff, cmap='hot', aspect='equal')
ax[0].set_title('Regular Difference')
ax[0].axis('off')

ax[1].imshow(hot07, cmap='hot', aspect='equal')
ax[1].set_title('Band 07 Hottest')
ax[1].axis('off')

ax[2].imshow(hot14, cmap='hot', aspect='equal')
ax[2].set_title('Band 14 Hottest')
ax[2].axis('off')

ax[3].imshow(hotboth, cmap='hot', aspect='equal')
ax[3].set_title('Hottest in Common')
ax[3].axis('off')

plt.show()

# %%
di
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True],
#        [False, False, False, ...,  True,  True,  True]])

# %%
hottest = diff[hotboth]
print(hottest.size == np.count_nonzero(hotboth == True))
print(str(100*hottest.size/(500**2)) + '% of the pixels are in common for the hottest of both bands.')
# Out:
# True
# 17.568% of the pixels are in common for the hottest of both bands.

# %%
hottest.max()
# Out:
# 95.78088

# %%
for file in os.listdir('../GOES_Files/test_files/multiband_npys'):
    band = np.load('../GOES_Files/test_files/multiband_npys/' + file)
    band = band[hotboth]
    r = np.corrcoef(hottest, band)
    print('band ' + file[:2] + ', r = ' + str(r[0][-1]))
# Out:
# band 01, r = 0.6127994124438517
# band 02, r = 0.6212117941420342
# band 03, r = 0.49091270235426204
# band 04, r = 0.4264040216615479
# band 05, r = 0.5221130144819266
# band 06, r = 0.6314717071992244
# band 07, r = 0.3741252841503637
# band 08, r = -0.014971231693156608
# band 09, r = -0.08693103779494572
# band 10, r = -0.2470459690127393
# band 11, r = -0.3458526480629087
# band 12, r = -0.2739214691233716
# band 13, r = -0.23354685828781382
# band 14, r = -0.2054106584540842
# band 15, r = -0.21181042548749063
# band 16, r = -0.3195446265614297
